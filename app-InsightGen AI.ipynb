# %%
# app.py
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import openai

# ----------------------
# Streamlit Page Config
# ----------------------
st.set_page_config(page_title="AI Data Storytelling Engine", layout="wide")
st.title("📊 AI Data Storytelling Engine")
st.caption("Upload your sales data → Generate insights → AI-powered business stories")

# ----------------------
# API Key Input (Safe)
# ----------------------
api_key = st.text_input(
    "🔑 Enter your OpenAI API Key",
    type="password",
    help="Your API key is never stored or shared"
)
if not api_key:
    st.warning("Please enter your OpenAI API key to continue")
    st.stop()
openai.api_key = api_key

# ----------------------
# File Upload
# ----------------------
uploaded_file = st.file_uploader(
    "📂 Upload Superstore Dataset (CSV)",
    type=["csv"]
)

if uploaded_file:
    df = pd.read_csv(uploaded_file, encoding="ISO-8859-1")
    st.success("Dataset loaded successfully!")
else:
    # Optional default dataset for testing
    df = pd.read_csv("data/superstore.csv", encoding="ISO-8859-1")
    st.info("Using default dataset")

# ----------------------
# Data Preparation
# ----------------------
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Order Quarter"] = df["Order Date"].dt.to_period("Q").astype(str)

# Summary Metrics
summary_metrics = {
    "Total Sales": round(df["Sales"].sum(), 2),
    "Total Profit": round(df["Profit"].sum(), 2),
    "Total Orders": df["Order ID"].nunique(),
    "Total Customers": df["Customer ID"].nunique()
}

# Sales Trend
trend = df.groupby("Order Quarter")[["Sales", "Profit"]].sum().reset_index()

# Category Performance
category_perf = df.groupby("Category")[["Sales","Profit"]].sum().reset_index()

# Region Performance
region_perf = df.groupby("Region")[["Sales","Profit"]].sum().reset_index()

# ----------------------
# Plot Functions
# ----------------------
def plot_trend(df):
    fig, ax = plt.subplots()
    ax.plot(df["Order Quarter"], df["Sales"], marker='o', label='Sales')
    ax.plot(df["Order Quarter"], df["Profit"], marker='s', label='Profit')
    ax.set_xlabel("Quarter")
    ax.set_ylabel("Amount ($)")
    ax.legend()
    plt.xticks(rotation=45)
    st.pyplot(fig)

def plot_bar(df, x_col, title):
    fig, ax = plt.subplots()
    ax.bar(df[x_col], df["Sales"], color="skyblue", label="Sales")
    ax.bar(df[x_col], df["Profit"], color="lightgreen", label="Profit", alpha=0.7)
    ax.set_ylabel("Amount ($)")
    ax.set_title(title)
    ax.legend()
    st.pyplot(fig)

# ----------------------
# AI Storytelling Function
# ----------------------
def generate_story(data):
    prompt = f"""
    You are a professional business analyst.
    Based on the following data, write an executive-level business narrative:

    {data}

    Include:
    - Overall performance
    - Key insights
    - One actionable recommendation
    Keep it professional, clear, and engaging.
    """
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.6,
        max_tokens=300
    )
    return response.choices[0].message.content

# ----------------------
# Tabs Layout
# ----------------------
tab1, tab2, tab3, tab4 = st.tabs(["Summary", "Sales Trend", "Category", "Region"])

with tab1:
    st.subheader("📌 Summary Metrics")
    st.json(summary_metrics)
    if st.button("🧠 Generate Summary Story", key="summary"):
        with st.spinner("Generating AI story..."):
            summary_story = generate_story(summary_metrics)
        st.subheader("📖 AI Summary Narrative")
        st.write(summary_story)

with tab2:
    st.subheader("📈 Sales & Profit Trend")
    plot_trend(trend)
    if st.button("🧠 Generate Sales Trend Story", key="trend"):
        with st.spinner("Generating AI story..."):
            sales_story = generate_story(trend.to_dict())
        st.subheader("📖 AI Sales Trend Narrative")
        st.write(sales_story)

with tab3:
    st.subheader("📊 Category Performance")
    plot_bar(category_perf, "Category", "Sales & Profit by Category")
    if st.button("🧠 Generate Category Story", key="category"):
        with st.spinner("Generating AI story..."):
            category_story = generate_story(category_perf.to_dict())
        st.subheader("📖 AI Category Narrative")
        st.write(category_story)

with tab4:
    st.subheader("📊 Region Performance")
    plot_bar(region_perf, "Region", "Sales & Profit by Region")
    if st.button("🧠 Generate Region Story", key="region"):
        with st.spinner("Generating AI story..."):
            region_story = generate_story(region_perf.to_dict())
        st.subheader("📖 AI Region Narrative")
        st.write(region_story)
# Out:
# 2026-02-05 15:21:07.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:07.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:08.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-05 15:21:09.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
